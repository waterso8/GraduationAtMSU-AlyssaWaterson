# %% [markdown]
# #### Welcome to the example notebook! I hope!
#
# This notebook runs through approximately what the data looks like when run successfully. First, we're going to pass in any needed libraries and my .py documents.
#
# .py documents implemented so far:
# $$ReadCSV.py$$
# $$calculate\_pvalues.py$$
# $$correlation\_matrix.py$$

# %%
import pandas as pd
import unittest
import calculate_pvalues as cpv
import correlation_matrix as cm
import ReadCSV as read
import csv
#exampledata = pd.read_csv('testdf.csv')
#del exampledata['Unnamed: 0']
#exampledata

# %% [markdown]
# For our progress, all the other libraries we need to use will be read in by the .py functions themselves.
#
# #### STEP 1: Have a .csv file prepared.
#
# We will first be using the ReadCSV library to simply read in our .csv file of choice. The one I am using (pending update) is called '$testdf.csv$'. Let's read it in.

# %%
read.ReadCSV('testdf.csv')
# Out:
#       math_placement_score     hsgpa  NonTC  Mix  APOnly  STEM  NONSTEM  \
# 0                 0.949721 -0.377643      0    1       0     0        1
# 1                 0.591251  0.892258      0    1       0     0        1
# 2                -0.125688  1.358752      0    1       0     1        0
# 3                 0.949721  0.607178      0    1       0     0        1
# 4                 1.845895  0.643461      0    0       1     1        0
# 5                 0.591251 -0.188454      0    1       0     0        1
# 6                -0.125688 -0.131438      0    1       0     1        0
# 7                -1.021861 -0.248061      0    1       0     1        0
# 8                -0.663392 -0.369868      0    1       0     1        0
# 9                 0.412017  0.386889      0    1       0     0        1
# 10                0.949721  1.957420      0    1       0     0        1
# 11               -0.842626  1.534983      0    0       1     0        1
# ...

# %% [markdown]
# #### STEP 2: Save the .csv file as a callable dataframe.
#
# STEP 1 was kinda just to make sure the ReadCSV command worked. It did, so let's save the actual table as a callable object. I'm calling it 'exampledata'.

# %%
exampledata = read.ReadCSV('testdf.csv')

# %% [markdown]
# #### STEP 3: Run calculate_pvalues library on exampledata.
#
# This is the pvalues section. We WILL get NaN entries if there are any columns with no variance. I'll fix this in future updates, but it completely runs!

# %%
cpv.calculate_pvalues(exampledata)
# Out:
# C:\Users\anime\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2530: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\anime\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2531: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\anime\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\anime\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\anime\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                      math_placement_score   hsgpa NonTC     Mix  APOnly  \
# math_placement_score                    0       0   NaN       0       0
# ...

# %% [markdown]
# #### STEP 4: Run correlation_matrix function on exampledata.
#
# Also relatively straightforward. We're just making sure all the .py files are running, after all. We'll see white squares where there are no variances, which I will fix in the future. For now, we can see red and blue squares where there are certain variances. Yay!

# %%
cm.correlation_matrix(exampledata)
